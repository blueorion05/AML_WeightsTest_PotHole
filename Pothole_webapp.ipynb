# %%
# !git clone https://github.com/blueorion05/AML_WeightsTest_PotHole
# Out:
# Cloning into 'AML_WeightsTest_PotHole'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 62 (delta 4), reused 4 (delta 3), pack-reused 53 (from 2)
# Receiving objects: 100% (62/62), 160.05 MiB | 28.98 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# Updating files: 100% (27/27), done.

# %%
# %cd AML_WeightsTest_PotHole
# !pip install -r requirements.txt
# Out:
# /content/AML_WeightsTest_PotHole
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 32.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 841.5 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install pyngrok
# !ngrok authtoken 'ahg-ccccccccccccccccccccccccc'
# Out:
# ...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !python app.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#  * ngrok tunnel available at https://86e7-35-204-180-149.ngrok-free.app
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8000
# Press CTRL+C to quit
# 127.0.0.1 - - [24/Mar/2025 01:19:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2025 01:19:05] "GET /static/js/functions.js HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2025 01:19:05] "GET /static/css/styles.css HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2025 01:19:06] "GET /get-models HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Mar/2025 01:19:06] "GET /favicon.ico HTTP/1.1" 404 -
#
# ...
